# %%
def agregar_elementos():

    lista = []
    while True:
        elemento = input("Ingrese un elemento para agregar a la lista (o 'salir' para terminar): ")
        if elemento.lower() == 'salir':
            break
        lista.append(elemento)
        print(f"Elemento '{elemento}' agregado. Lista actual: {lista}")
    return lista

lista_final = agregar_elementos()
print(f"Lista final: {lista_final}")
# Out:
# Ingrese un elemento para agregar a la lista (o 'salir' para terminar): 3
# Elemento '3' agregado. Lista actual: ['3']
# Ingrese un elemento para agregar a la lista (o 'salir' para terminar): 5
# Elemento '5' agregado. Lista actual: ['3', '5']
# Ingrese un elemento para agregar a la lista (o 'salir' para terminar): 7
# Elemento '7' agregado. Lista actual: ['3', '5', '7']
# Ingrese un elemento para agregar a la lista (o 'salir' para terminar): salir
# Lista final: ['3', '5', '7']
